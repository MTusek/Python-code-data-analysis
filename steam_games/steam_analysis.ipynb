# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\Marko\Desktop\data_folder\steam_games\games_march2025_cleaned.csv")

# %%
df
# Out:
#          appid                             name release_date  required_age  \
# 0          730                 Counter-Strike 2   2012-08-21             0
# 1       578080              PUBG: BATTLEGROUNDS   2017-12-21             0
# 2          570                           Dota 2   2013-07-09             0
# 3       271590        Grand Theft Auto V Legacy   2015-04-13            17
# 4       359550  Tom Clancy's Rainbow Six® Siege   2015-12-01            17
# ...        ...                              ...          ...           ...
# 89613  2115110                      Outrun Them   2024-02-29             0
# 89614  1174200      Lands of Pharaoh: Episode 1   2020-01-07             0
# 89615  1160190                       Player One   2019-10-10             0
# 89616  3380340                       DragonRoad   2025-01-25             0
# 89617   763730               Ragtag Adventurers   2018-03-01             0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89618 entries, 0 to 89617
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     89618 non-null  int64
#  1   name                      89618 non-null  object
#  2   release_date              89618 non-null  object
#  3   required_age              89618 non-null  int64
#  4   price                     89618 non-null  float64
#  5   dlc_count                 89618 non-null  int64
#  6   detailed_description      89421 non-null  object
#  7   about_the_game            89398 non-null  object
#  8   short_description         89498 non-null  object
#  9   reviews                   10401 non-null  object
#  10  header_image              89618 non-null  object
#  11  website                   41114 non-null  object
#  12  support_url               44110 non-null  object
# ...

# %%
df['name'].head(20)
# Out:
# 0                    Counter-Strike 2
# 1                 PUBG: BATTLEGROUNDS
# 2                              Dota 2
# 3           Grand Theft Auto V Legacy
# 4     Tom Clancy's Rainbow Six® Siege
# 5                     Team Fortress 2
# 6                            Terraria
# 7                                Rust
# 8                         Garry's Mod
# 9                       Apex Legends™
# 10                 Black Myth: Wukong
# 11           The Witcher 3: Wild Hunt
# 12                         ELDEN RING
# 13                     Stardew Valley
# 14                     Cyberpunk 2077
# 15                      HELLDIVERS™ 2
# 16                    Baldur's Gate 3
# 17             Euro Truck Simulator 2
# 18              Red Dead Redemption 2
# 19                          Destiny 2
# Name: name, dtype: object

# %%
df[['name', 'price']]
# Out:
#                                   name  price
# 0                     Counter-Strike 2   0.00
# 1                  PUBG: BATTLEGROUNDS   0.00
# 2                               Dota 2   0.00
# 3            Grand Theft Auto V Legacy   0.00
# 4      Tom Clancy's Rainbow Six® Siege   3.99
# ...                                ...    ...
# 89613                      Outrun Them   3.99
# 89614      Lands of Pharaoh: Episode 1  10.00
# 89615                       Player One   1.99
# 89616                       DragonRoad  29.99
# 89617               Ragtag Adventurers   9.99
#
# [89618 rows x 2 columns]

# %%
#Ispiši podatke o Geometry Dashu (index = 35)
df.iloc[35]
# Out:
# appid                                                                                                              322170
# name                                                                                                        Geometry Dash
# release_date                                                                                                   2014-12-22
# required_age                                                                                                            0
# price                                                                                                                4.99
#                                                                      ...
# tags                  {'Difficult': 3733, 'Music': 2945, 'Level Editor': 2851, 'Great Soundtrack': 2818, 'Precision Pl...
# pct_pos_total                                                                                                          93
# ...

# %%
#Ispiši cijenu(index stupca) od Terrarije (index retka 6) i GD (index retka 35)
df.iloc[[6,35],4]
# Out:
# 6     9.99
# 35    4.99
# Name: price, dtype: float64

# %%
df.columns
# Out:
# Index(['appid', 'name', 'release_date', 'required_age', 'price', 'dlc_count',
#        'detailed_description', 'about_the_game', 'short_description',
#        'reviews', 'header_image', 'website', 'support_url', 'support_email',
#        'windows', 'mac', 'linux', 'metacritic_score', 'metacritic_url',
#        'achievements', 'recommendations', 'notes', 'supported_languages',
#        'full_audio_languages', 'packages', 'developers', 'publishers',
#        'categories', 'genres', 'screenshots', 'movies', 'user_score',
#        'score_rank', 'positive', 'negative', 'estimated_owners',
#        'average_playtime_forever', 'average_playtime_2weeks',
#        'median_playtime_forever', 'median_playtime_2weeks', 'discount',
#        'peak_ccu', 'tags', 'pct_pos_total', 'num_reviews_total',
#        'pct_pos_recent', 'num_reviews_recent'],
#       dtype='object')

# %%
#Razlika između genres i tags
df.genres
df.tags
# Out:
# 0                                              ['Action', 'Free To Play']
# 1        ['Action', 'Adventure', 'Massively Multiplayer', 'Free To Play']
# 2                                  ['Action', 'Strategy', 'Free To Play']
# 3                                                 ['Action', 'Adventure']
# 4                                                              ['Action']
#                                        ...
# 89613                                           ['Indie', 'Early Access']
# 89614                        ['Action', 'Adventure', 'Indie', 'Strategy']
# 89615                                           ['Indie', 'Early Access']
# 89616                      ['Adventure', 'RPG', 'Simulation', 'Strategy']
# 89617                                                 ['Action', 'Indie']
# Name: genres, Length: 89618, dtype: object

# %% [markdown]
# Provjeri jesu li genrovi pravilno dodijeljeni igrama kao i user-defined tags

# %%
df['genres'].value_counts()
# Out:
# genres
# ['Casual', 'Indie']                                                       5099
# ['Action', 'Indie']                                                       4692
# ['Action', 'Adventure', 'Indie']                                          4103
# ['Adventure', 'Indie']                                                    3432
# ['Adventure', 'Casual', 'Indie']                                          2881
#                                                                           ...
# ['Indie', 'Utilities', 'Video Production']                                   1
# ['Violent', 'Adventure', 'Indie', 'Early Access']                            1
# ['Audio Production', 'Photo Editing', 'Utilities', 'Video Production']       1
# ['Action', 'Adventure', 'Casual', 'Sports', 'Strategy']                      1
# ['Gore', 'Action', 'Early Access']                                           1
# Name: count, Length: 2689, dtype: int64

# %%
df['tags'].value_counts()
# Out:
# tags
# []                                                                                                                                                                                                                                                                                                                                                                                                           16872
# {'Indie': 21, 'Casual': 21}                                                                                                                                                                                                                                                                                                                                                                                    109
# ...

# %% [markdown]
# Zaključak: Većina igri nema definirane tagove, ali za definirane se podudaraju uz dodatak: hidden object

# %%
df.loc[0:7,'name':'price']
# Out:
#                               name release_date  required_age  price
# 0                 Counter-Strike 2   2012-08-21             0   0.00
# 1              PUBG: BATTLEGROUNDS   2017-12-21             0   0.00
# 2                           Dota 2   2013-07-09             0   0.00
# 3        Grand Theft Auto V Legacy   2015-04-13            17   0.00
# 4  Tom Clancy's Rainbow Six® Siege   2015-12-01            17   3.99
# 5                  Team Fortress 2   2007-10-10             0   0.00
# 6                         Terraria   2011-05-16             0   9.99
# 7                             Rust   2018-02-08             0  39.99

# %%
#Ispis prvih 30 igrica sa nazivom i cijenom
pd.set_option('display.max_rows',30)
df[['name','price']].head(30)
# Out:
#                                name  price
# 0                  Counter-Strike 2   0.00
# 1               PUBG: BATTLEGROUNDS   0.00
# 2                            Dota 2   0.00
# 3         Grand Theft Auto V Legacy   0.00
# 4   Tom Clancy's Rainbow Six® Siege   3.99
# 5                   Team Fortress 2   0.00
# 6                          Terraria   9.99
# 7                              Rust  39.99
# 8                       Garry's Mod   5.99
# 9                     Apex Legends™   0.00
# 10               Black Myth: Wukong  59.99
# 11         The Witcher 3: Wild Hunt  39.99
# 12                       ELDEN RING  59.99
# 13                   Stardew Valley  14.99
# 14                   Cyberpunk 2077  59.99
# 15                    HELLDIVERS™ 2  39.99
# 16                  Baldur's Gate 3  59.99
# 17           Euro Truck Simulator 2  19.99
# 18            Red Dead Redemption 2  59.99
# 19                        Destiny 2   0.00
# 20                     Phasmophobia  19.99
# ...

# %% [markdown]
# Analiza koliko igri je za koji OS

# %%
df['windows'].value_counts()
# Out:
# windows
# True     89588
# False       30
# Name: count, dtype: int64

# %%
df['linux'].value_counts()
# Out:
# linux
# False    76991
# True     12627
# Name: count, dtype: int64

# %%
df['mac'].value_counts()
# Out:
# mac
# False    72180
# True     17438
# Name: count, dtype: int64

# %%
df['supported_languages'].value_counts()
# Out:
# supported_languages
# ...

# %%
#df.set_index('name', inplace=True)
df.loc['Terraria':'Warframe']
# Out:
#                          release_date  required_age  price  dlc_count  \
# name
# Terraria                   2011-05-16             0   9.99          2
# Rust                       2018-02-08             0  39.99          4
# Garry's Mod                2006-11-29             0   5.99          0
# Apex Legends™              2020-11-04             0   0.00          0
# Black Myth: Wukong         2024-08-19            13  59.99          2
# The Witcher 3: Wild Hunt   2015-05-18            17  39.99         22
# ELDEN RING                 2022-02-24            16  59.99          2
# Stardew Valley             2016-02-26             0  14.99          1
# Cyberpunk 2077             2020-12-09            17  59.99          3
# HELLDIVERS™ 2              2024-02-08            17  39.99          1
# Baldur's Gate 3            2023-08-03            17  59.99          2
# Euro Truck Simulator 2     2012-10-12             0  19.99         98
# ...

# %% [markdown]
# Pronađi sve besplatne igre :D

# %%
#df.set_index('price', inplace=True)
df.loc[0.00, 'name']
# Out:
# price
# 0.0                                 Counter-Strike 2
# 0.0                              PUBG: BATTLEGROUNDS
# 0.0                                           Dota 2
# 0.0                        Grand Theft Auto V Legacy
# 0.0                                  Team Fortress 2
#                            ...
# 0.0                                     BLASTER LiLO
# 0.0                                      Party Words
# 0.0                                    Dan's Odyssey
# 0.0                        DO_OR_DIE Hunt to Survive
# 0.0    Might & Magic: Heroes VI - Shades of Darkness
# Name: name, Length: 14160, dtype: object

# %%
#Postavlja appid umjesto default indexa
df = pd.read_csv(r"C:\Users\Marko\Desktop\data_folder\steam_games\games_march2025_cleaned.csv", index_col='appid')
# Out:
#                                    name release_date  required_age  price  \
# appid
# 730                    Counter-Strike 2   2012-08-21             0   0.00
# 578080              PUBG: BATTLEGROUNDS   2017-12-21             0   0.00
# 570                              Dota 2   2013-07-09             0   0.00
# 271590        Grand Theft Auto V Legacy   2015-04-13            17   0.00
# 359550  Tom Clancy's Rainbow Six® Siege   2015-12-01            17   3.99
#
#         dlc_count  \
# appid
# 730             1
# 578080          0
# 570             2
# 271590          0
# 359550          9
#
#                                                                                        detailed_description  \
# appid
# 730     For over two decades, Counter-Strike has offered an elite competitive experience, one shaped by ...
# 578080  LAND, LOOT, SURVIVE! Play PUBG: BATTLEGROUNDS for free. Land on strategic locations, loot weapon...
# ...

# %%
df = pd.read_csv(r"C:\Users\Marko\Desktop\data_folder\steam_games\games_march2025_cleaned.csv")

# %%
#Sortiraj abecedno
df.set_index('name',inplace=True)
df.sort_index()
# Out:
#                                                 appid release_date  \
# name
# ! Shakabula *                                 2556940   2023-10-13
# ! That Bastard Is Trying To Steal Our Gold !   449940   2016-03-03
# ! Wild Russia !                               1287250   2020-04-28
# !AnyWay!                                       866510   2018-06-06
# !LABrpgUP!                                     870990   2018-06-13
# ...                                               ...          ...
# 👑万千网友共修仙👑                                     1843330   2022-10-29
# 🔴 Circles                                      460250   2017-02-17
# 🚀 Human Rocket Person                          965340   2018-11-14
# 🧠 OUT OF THE BOX                               576960   2018-07-19
# 𣸩                                             2639280   2023-12-29
#
#                                               required_age  price  dlc_count  \
# name
# ...

# %%
#Besplatne igre :D
povoljna_cijena = df['price']==0
free_games=df[povoljna_cijena]

output = pd.DataFrame({'Name': free_games.name, 'About': free_games.short_description})
output.to_csv('free_games.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
#Indie igre
import pandas as pd
df = pd.read_csv(r"C:\Users\Marko\Desktop\data_folder\steam_games\games_march2025_cleaned.csv")
indie_games = df['tags'].str.contains('Indie', na=False)
df.loc[indie_games]
# Out:
#          appid                         name release_date  required_age  price  \
# 6       105600                     Terraria   2011-05-16             0   9.99
# 7       252490                         Rust   2018-02-08             0  39.99
# 8         4000                  Garry's Mod   2006-11-29             0   5.99
# 13      413150               Stardew Valley   2016-02-26             0  14.99
# 17      227300       Euro Truck Simulator 2   2012-10-12             0  19.99
# ...        ...                          ...          ...           ...    ...
# 89612   801660                Swapper Tiles   2018-05-07             0   0.99
# 89613  2115110                  Outrun Them   2024-02-29             0   3.99
# 89614  1174200  Lands of Pharaoh: Episode 1   2020-01-07             0  10.00
# 89615  1160190                   Player One   2019-10-10             0   1.99
# 89617   763730           Ragtag Adventurers   2018-03-01             0   9.99
#
# ...

# %%
#Multiplayer igre
indie_games = df['tags'].str.contains('Multiplayer', na=False)
df.loc[indie_games]
# Out:
#          appid                             name release_date  required_age  \
# 0          730                 Counter-Strike 2   2012-08-21             0
# 1       578080              PUBG: BATTLEGROUNDS   2017-12-21             0
# 2          570                           Dota 2   2013-07-09             0
# 3       271590        Grand Theft Auto V Legacy   2015-04-13            17
# 4       359550  Tom Clancy's Rainbow Six® Siege   2015-12-01            17
# ...        ...                              ...          ...           ...
# 89588  3245910                         Baratrum   2024-12-11             0
# 89599  2935280                         Zector 7   2024-10-25             0
# 89601  1527230                          UC KART   2021-03-12             0
# 89608  3065390                Caribbean Pirates   2024-07-24             0
# 89616  3380340                       DragonRoad   2025-01-25             0
#
# ...

# %%
#Igre koje su "free-to-play"

free_to_play = df['tags'].str.contains('Free to Play', na=False)
df.loc[free_to_play]
# Out:
#          appid                       name release_date  required_age  price  \
# 2          570                     Dota 2   2013-07-09             0   0.00
# 5          440            Team Fortress 2   2007-10-10             0   0.00
# 9      1172470              Apex Legends™   2020-11-04             0   0.00
# 19     1085660                  Destiny 2   2019-10-01             0   0.00
# 22      230410                   Warframe   2013-03-25            17   0.00
# ...        ...                        ...          ...           ...    ...
# 88517  3071270                      Linum   2024-07-19             0   0.00
# 88969   937160             BRING IT DOWN!   2019-10-22             0   6.99
# 89012  2620950               UnderOneRoof   2023-10-15             0   0.00
# 89014   773850                        WT2   2020-01-02             0   0.00
# 89510  2227830  DO_OR_DIE Hunt to Survive   2023-01-03             0   0.00
#
# ...

# %%
povoljna_cijena = df['price']==0
free_games=df[povoljna_cijena]

besplatna_reklama = df['tags'].str.contains('Free to Play', na=False)
free_to_play=df[besplatna_reklama]

# %%
#Provjera što pokazuju tagovi i cijene - većina igri je besplatna jer je možda neka promocija i/ili ima demo -> iščitano i pogledano u tablici
free_games
free_to_play
# Out:
#          appid                                           name release_date  \
# 0          730                               Counter-Strike 2   2012-08-21
# 1       578080                            PUBG: BATTLEGROUNDS   2017-12-21
# 2          570                                         Dota 2   2013-07-09
# 3       271590                      Grand Theft Auto V Legacy   2015-04-13
# 5          440                                Team Fortress 2   2007-10-10
# ...        ...                                            ...          ...
# 89423   999750                                   BLASTER LiLO   2018-12-28
# 89434  1992530                                    Party Words   2022-12-06
# 89450  2182170                                  Dan's Odyssey   2022-11-03
# 89510  2227830                      DO_OR_DIE Hunt to Survive   2023-01-03
# 89574   229790  Might & Magic: Heroes VI - Shades of Darkness   2013-05-02
#
#        required_age  price  dlc_count  \
# ...

# %%
df.apply(len)
# Out:
# appid                       89618
# name                        89618
# release_date                89618
# required_age                89618
# price                       89618
# dlc_count                   89618
# detailed_description        89618
# about_the_game              89618
# short_description           89618
# reviews                     89618
# header_image                89618
# website                     89618
# support_url                 89618
# support_email               89618
# windows                     89618
# mac                         89618
# linux                       89618
# metacritic_score            89618
# metacritic_url              89618
# achievements                89618
# recommendations             89618
# notes                       89618
# supported_languages         89618
# full_audio_languages        89618
# packages                    89618
# developers                  89618
# publishers                  89618
# ...

# %%
df.sort_values('price')
# Out:
#          appid                                name release_date  required_age  \
# 43787  3361890                             V-Shift   2025-01-04             0
# 43781   718960                       The Flesh God   2017-11-02             0
# 79      433850                    Z1 Battle Royale   2018-02-28             0
# 77      698780          Doki Doki Literature Club!   2017-10-06             0
# 76      700330              SCP: Secret Laboratory   2017-12-29             0
# ...        ...                                 ...          ...           ...
# 72266   253670               Aartform Curvy 3D 3.0   2013-11-12             0
# 84664  3013840                           True Love   2024-06-27             0
# 64631  1200520   Ascent Free-Roaming VR Experience   2019-12-27             0
# 81168  2499620                   The Leverage Game   2023-08-25             0
# 60133  2504210  The Leverage Game Business Edition   2023-08-26             0
#
# ...

# %%
#
